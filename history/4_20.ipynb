# %%
from route_generator import *

# %%
graph
# Out:
# {'0_0': ['0'],
#  '0': ['0_0', '0_1', '0_2'],
#  '0_1': ['0', '1_0'],
#  '0_2': ['0'],
#  '1_0': ['1', '0_1'],
#  '1': ['1_0', '1_1', '1_2', '1_3'],
#  '1_1': ['1', '4_3'],
#  '1_2': ['1', '2_0'],
#  '1_3': ['1'],
#  '2_0': ['2', '1_2'],
#  '2': ['2_0', '2_1', '2_2'],
#  '2_1': ['2', '3_3'],
#  '2_2': ['2'],
#  '3_0': ['3', '4_2'],
#  '3': ['3_0', '3_1', '3_2', '3_3'],
#  '3_1': ['3'],
#  '3_2': ['3'],
#  '3_3': ['3', '2_1'],
#  '4_0': ['4'],
#  '4': ['4_0', '4_1', '4_2', '4_3'],
#  '4_1': ['4'],
#  '4_2': ['4', '3_0'],
#  '4_3': ['4', '1_1']}

# %%
nodes
# Out:
# ['0_0', '0_2', '1_3', '2_2', '4_0', '4_1', '3_1', '3_2']

# %%
results = []
for node1 in nodes:
    for node2 in nodes:
        results.append(bfs_shortest_paths(node1, node2))

# %%
for result in results:
    if len(result) == 1:
        results.remove(result)

# %%
len(results)
# Out:
# 38

# %%
results
# Out:
# [[['0_0', '0', '0_2']],
#  [['0_0', '0', '0_1', '1_0', '1', '1_2', '2_0', '2', '2_2']],
#  [['0_0', '0', '0_1', '1_0', '1', '1_1', '4_3', '4', '4_1']],
#  [['0_0', '0', '0_1', '1_0', '1', '1_1', '4_3', '4', '4_2', '3_0', '3', '3_1'],
#   ['0_0',
#    '0',
#    '0_1',
#    '1_0',
#    '1',
#    '1_2',
#    '2_0',
#    '2',
#    '2_1',
#    '3_3',
#    '3',
#    '3_1']],
#  [['0_0', '0', '0_1', '1_0', '1', '1_1', '4_3', '4', '4_2', '3_0', '3', '3_2'],
#   ['0_0',
#    '0',
#    '0_1',
#    '1_0',
#    '1',
#    '1_2',
#    '2_0',
#    '2',
#    '2_1',
#    '3_3',
#    '3',
#    '3_2']],
#  [['0_2']],
#  [['0_2', '0', '0_1', '1_0', '1', '1_2', '2_0', '2', '2_2']],
#  [['0_2', '0', '0_1', '1_0', '1', '1_1', '4_3', '4', '4_1']],
#  [['0_2', '0', '0_1', '1_0', '1', '1_1', '4_3', '4', '4_2', '3_0', '3', '3_1'],
#   ['0_2',
#    '0',
#    '0_1',
#    '1_0',
#    '1',
#    '1_2',
#    '2_0',
#    '2',
#    '2_1',
#    '3_3',
#    '3',
#    '3_1']],
# ...

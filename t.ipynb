# %%
import pandas as pd
import numpy as np

# %%
a = pd.read_excel('./output_volume_aug.xlsx')

# %%
a
# Out:
#      R109  R106  R104   R99  R91  R81  R48  R39   R38   R37  ...   R28    R6  \
# 0     431   301   167   316  165  158   90   88   232   328  ...   118   300
# 1     295   214    96   224  108  103   59   59   161   262  ...   108   243
# 2     212   168    88   152   93   93   50   49   128   179  ...    71   167
# 3     152   245   136   114   71   68   38   36   134   176  ...    82   139
# 4     253   399   236   190  159  161   87   88   312   298  ...   141   219
# ..    ...   ...   ...   ...  ...  ...  ...  ...   ...   ...  ...   ...   ...
# 115  1603  1399   701  1165  763  738  434  437  1233  1831  ...  1272  2452
# 116  1622  1193   653  1158  700  673  346  350   867  1798  ...  1048  1873
# 117  1494  1043   573  1124  531  527  264  252   774  1477  ...   744  1353
# 118  1302   825   480   983  451  438  247  245   648  1323  ...   463  1282
# 119   892   542   320   677  319  306  178  182   449   873  ...   298   845
#
# ...

# %%
temp = (a.iloc[:,-6:]*1.5).astype(int)

# %%
a.iloc[:,-6:] = temp

# %%
a.to_excel('./output_volume_aug.xlsx', index=0)
